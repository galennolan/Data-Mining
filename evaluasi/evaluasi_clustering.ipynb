# %%
# Import libraries yang dibutuhkan
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score
from sklearn.metrics import adjusted_rand_score, normalized_mutual_info_score
from sklearn.decomposition import PCA

# Membuat dataset contoh untuk clustering
X, y = make_blobs(n_samples=300, centers=4, cluster_std=0.60, random_state=0)

# Menggunakan KMeans untuk clustering
kmeans = KMeans(n_clusters=4, random_state=42)
y_pred = kmeans.fit_predict(X)

# 1. Silhouette Score
sil_score = silhouette_score(X, y_pred)
print(f'Silhouette Score: {sil_score:.4f}')

# 2. Davies-Bouldin Index
db_index = davies_bouldin_score(X, y_pred)
print(f'Davies-Bouldin Index: {db_index:.4f}')

# 3. Calinski-Harabasz Index
ch_index = calinski_harabasz_score(X, y_pred)
print(f'Calinski-Harabasz Index: {ch_index:.4f}')

# 4. Adjusted Rand Index
ari = adjusted_rand_score(y, y_pred)
print(f'Adjusted Rand Index: {ari:.4f}')

# 5. Normalized Mutual Information
nmi = normalized_mutual_info_score(y, y_pred)
print(f'Normalized Mutual Information: {nmi:.4f}')

# 6. Scatter Plot (Visualisasi Clustering)
# Menggunakan PCA untuk mereduksi dimensi agar bisa divisualisasikan
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

plt.figure(figsize=(8, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_pred, cmap='viridis', marker='o')
plt.title('Clustering Visualization (KMeans)', fontsize=16)
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.colorbar(label='Cluster')
plt.show()
# Out:
# Silhouette Score: 0.6820
# Davies-Bouldin Index: 0.4376
# Calinski-Harabasz Index: 1210.0899
# Adjusted Rand Index: 1.0000
# Normalized Mutual Information: 1.0000
