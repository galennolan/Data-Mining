# %%
# %pip install tensorflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf

a = tf.constant(2)
b = tf.constant(3)

c = tf.add(a, b)

# TensorFlow 2.x menggunakan Eager Execution secara default
result = c.numpy()
print(result)
# Out:
# 5

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Membuat dataset sederhana
x = np.array([1, 2, 3, 4, 5], dtype=float)
y = np.array([1, 3, 5, 7, 9], dtype=float)

# Membuat model regresi linear
model = keras.Sequential([
    layers.Dense(units=1, input_shape=[1])
])

model.compile(optimizer='sgd', loss='mean_squared_error')

# Melatih model
model.fit(x, y, epochs=50)

# Simpan model dalam format .h5
model.save('linear_regression_model.h5')
# Out:
# Epoch 1/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 551ms/step - loss: 11.2473
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 6.6724
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 4.0056
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 2.4507
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 1.5438
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 1.0146
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.7053
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.5244
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.4182
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.3555
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - loss: 0.3182
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.2958
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2819
# Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.2731
# Epoch 15/50
# ...

# %%
# %pip install tensorflowjs -i https://mirrors.aliyun.com/pypi/simple/
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# ...
#      ---------------------------------------- 0.0/89.1 kB ? eta -:--:--
#      ---------------------------------------- 0.0/89.1 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/89.1 kB ? eta -:--:--
#      ------------- ------------------------ 30.7/89.1 kB 330.3 kB/s eta 0:00:01
#      ------------- ------------------------ 30.7/89.1 kB 330.3 kB/s eta 0:00:01
#      ------------- ------------------------ 30.7/89.1 kB 330.3 kB/s eta 0:00:01
#      ------------- ------------------------ 30.7/89.1 kB 330.3 kB/s eta 0:00:01
#      ------------- ------------------------ 30.7/89.1 kB 330.3 kB/s eta 0:00:01
#      ------------- ------------------------ 30.7/89.1 kB 330.3 kB/s eta 0:00:01
#      ------------- ------------------------ 30.7/89.1 kB 330.3 kB/s eta 0:00:01
#      --------------------- ---------------- 51.2/89.1 kB 100.9 kB/s eta 0:00:01
# ...

# %% [markdown]
# Convert h5 model ke js

# %%
import tensorflowjs as tfjs
from tensorflow.keras.models import load_model

# Muat model Keras
model = load_model('linear_regression_model.h5')

# Ekspor model ke format TensorFlow.js
tfjs.converters.save_keras_model(model, 'linear_regression_model_js')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import tensorflowjs as tfjs
#       2 from tensorflow.keras.models import load_model
#       4 # Muat model Keras
#
# File c:\Users\Galih Setiawan\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflowjs\__init__.py:21
#      18 from __future__ import print_function
#      20 # pylint: disable=unused-imports
# ---> 21 from tensorflowjs import converters
#      22 from tensorflowjs import quantization
#      23 from tensorflowjs import version
#
# File c:\Users\Galih Setiawan\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflowjs\converters\__init__.py:21
#      18 from __future__ import print_function
#      20 # pylint: disable=unused-imports,line-too-long
# ---> 21 from tensorflowjs.converters.converter import convert
# ...
